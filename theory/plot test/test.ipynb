# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 1, 1001)
y = 3*x
plt.figure(figsize=(3.8, 2.7))
plt.plot(x,y)
plt.plot(x,x**2)
plt.savefig("test.png", dpi=600)
plt.savefig("test.pgf", dpi=600)
